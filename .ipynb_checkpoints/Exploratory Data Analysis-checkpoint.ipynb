# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# %%
pd.set_option('display.max_columns',None)
df = pd.read_csv('cleaned_salary_data.csv')
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\r\nLocation: Albuquerque, NM\r\...     3.8
# 1  What You Will Do:\r\n\r\nI. General Summary\r\...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\r\nJob ID: 310709\r...     3.8
# 4  Data Scientist\r\nAffinity Solutions / Marketi...     2.9
#
#                                    Company Name         Location  \
# 0                      Tecolote Research\r\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\r\n3.4    Linthicum, MD
# ...

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  Minimum Salary  Maximum Salary  \
# count  742.000000   742.000000  742.000000      742.000000      742.000000
# mean     3.618868  1837.154987    0.032345       74.719677      128.149596
# std      0.801210   497.183763    0.177034       30.980593       45.220324
# min     -1.000000    -1.000000    0.000000       15.000000       16.000000
# 25%      3.300000  1939.000000    0.000000       52.000000       96.000000
# 50%      3.700000  1988.000000    0.000000       69.500000      124.000000
# 75%      4.000000  2007.000000    0.000000       91.000000      155.000000
# max      5.000000  2019.000000    1.000000      202.000000      306.000000
#
#        Average Salary  isheadquarters  Company Age    python_r   tableau_r  \
# count      742.000000      742.000000   742.000000  742.000000  742.000000
# mean       100.626011        0.557951    47.524259    0.528302    0.199461
# ...

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### Distribution plot and Box plot

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.distplot(df.Rating, kde = True, bins=15, fit=norm)

plt.subplot(1,2,2)
df.boxplot(column = 'Rating')
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.distplot(df['Average Salary'], kde = True, bins=15, fit=norm)

plt.subplot(1,2,2)
df.boxplot(column = 'Average Salary')
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.distplot(df['Company Age'], kde = True, bins=15, fit=norm)

plt.subplot(1,2,2)
df.boxplot(column = 'Company Age')
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.distplot(df['dcrpn_len'], kde = True, bins=15, fit=norm)

plt.subplot(1,2,2)
df.boxplot(column = 'dcrpn_len')
plt.show()

# %% [markdown]
# #### Categorical variables

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'Minimum Salary', 'Maximum Salary', 'Average Salary', 'Company',
#        'State', 'City', 'isheadquarters', 'Company Age', 'python_r',
#        'tableau_r', 'excel_r', 'sql', 'Job_cat', 'Seniority', 'dcrpn_len',
#        'Emp_no'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters','Type of ownership', 'Industry', 'Sector','Revenue','Company',
             'State','isheadquarters','python_r','tableau_r', 'excel_r', 'sql','Job_cat', 'Seniority']]
df_cat.head()
# Out:
#           Location    Headquarters   Type of ownership  \
# 0  Albuquerque, NM      Goleta, CA   Company - Private
# 1    Linthicum, MD   Baltimore, MD  Other Organization
# 2   Clearwater, FL  Clearwater, FL   Company - Private
# 3     Richland, WA    Richland, WA          Government
# 4     New York, NY    New York, NY   Company - Private
#
#                            Industry                        Sector  \
# 0               Aerospace & Defense           Aerospace & Defense
# 1  Health Care Services & Hospitals                   Health Care
# 2                 Security Services             Business Services
# 3                            Energy  Oil, Gas, Energy & Utilities
# 4           Advertising & Marketing             Business Services
#
#                             Revenue                                Company  \
# 0         $50 to $100 million (USD)                      Tecolote Research
# 1            $2 to $5 billion (USD)  University of Maryland Medical System
# ...

# %% [markdown]
# ### Bar plots of categorical variables

# %%
for i in df_cat.columns:
    a = df_cat[i].value_counts()
    if len(a) < 61:
        gph = sns.barplot(x=a.index, y=a.values)
        gph.set_xticklabels(gph.get_xticklabels(), rotation = 90)
        plt.title(i)
        plt.show()

# %%
# display only top 25 since data has too many values
for i in df_cat.columns:
    a = df_cat[i].value_counts()
    if len(a) > 61:
        gph = sns.barplot(x=a.index[:25], y=a.values[:25])
        gph.set_xticklabels(gph.get_xticklabels(), rotation = 90)
        plt.title(i)
        plt.show()

# %% [markdown]
# ### Analysing the Relation of Salary with different variables

# %%
pd.pivot_table(index=['Job_cat','Seniority'],values = 'Average Salary', data = df)
# Out:
#                                      Average Salary
# Job_cat                   Seniority
# Analyst                   Junior          47.555556
#                           Senior          79.092593
#                           na              62.873134
# Data Engineer             Junior         118.900000
#                           Senior         124.689189
#                           na              95.743421
# Data Scientist            Junior          84.250000
#                           Senior         138.956522
#                           na             107.538251
# Director                  Junior         140.000000
#                           na             173.375000
# Machine Learning Engineer Senior         142.071429
#                           na             119.133333
# Manager                   na              84.022727
# Research Scientist        Junior          87.500000
#                           Senior         136.250000
# ...

# %%
pd.set_option('display.max_rows',None)
pd.pivot_table(index=['State','Job_cat'],values = 'Average Salary', data = df)
# Out:
#                                  Average Salary
# State Job_cat
# AL    Analyst                         62.200000
#       Data Engineer                   65.000000
#       na                              43.750000
# AZ    Analyst                         55.000000
#       Data Engineer                   79.500000
#       Data Scientist                  69.500000
#       na                             124.500000
# CA    Analyst                         85.250000
#       Data Engineer                  129.540000
#       Data Scientist                 142.522059
#       Machine Learning Engineer      177.300000
#       Manager                         80.611111
#       Research Scientist              87.500000
#       na                             100.384615
# CO    Analyst                         29.500000
#       Data Engineer                   99.000000
#       Data Scientist                 108.666667
#       Machine Learning Engineer      100.500000
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'hourly',
#        'Minimum Salary', 'Maximum Salary', 'Average Salary', 'Company',
#        'State', 'City', 'isheadquarters', 'Company Age', 'python_r',
#        'tableau_r', 'excel_r', 'sql', 'Job_cat', 'Seniority', 'dcrpn_len',
#        'Emp_no'],
#       dtype='object')

# %%
df_pivots = [['Type of ownership','Industry', 'Sector', 'Revenue', 'hourly','isheadquarters','python_r','tableau_r',
              'excel_r', 'sql']]
